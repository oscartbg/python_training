# %% [markdown]
# ## Publication-grade Plot Introduction
#
# The aim of this projects is to introduce you to data visualization with Python as concrete and as consistent as possible. Using what you’ve learned; download the London Crime Dataset from Kaggle. This dataset is a record of crime in major metropolitan areas, such as London, occurs in distinct patterns. This data covers the number of criminal reports by month, LSOA borough, and major/minor category from Jan 2008-Dec 2016.
#
# This dataset contains:
#
# * `lsoa_code`: this represents a policing area
# * `borough`: the london borough for which the statistic is related
# * `major_category`: the major crime category
# * `minor_category`: the minor crime category
# * `value`: the count of the crime for that particular borough, in that particular month
# * `year`: the year of the summary statistic
# * `month`: the month of the summary statistic
#
# Formulate a question and derive a statistical hypothesis test to answer the question. You have to demonstrate that you’re able to make decisions using data in a scientific manner. And the important things, Visualized the data. Examples of questions can be:
#
# * What is the change in the number of crime incidents from 2011 to 2016?
# * What were the top 3 crimes per borough in 2016?
#
# Please make sure that you have completed the session for this course, namely Advanced Visualization which is part of this Program.
#
# Note: You can take a look at Project Rubric below:
#
# Criteria |	Meet Expectations
# ---|---
# Area Plot |	Mengimplementasikan Area Plot Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik
# Histogram |	Mengimplementasikan Histogram Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
# Bar Chart | Mengimplementasikan Bar Chart Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
# Pie Chart |	Mengimplementasikan Pie Chart Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
# Box Plot |	Mengimplementasikan Box Plot Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
# Scatter Plot |	Mengimplementasikan Scatter Plot Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
# Word Clouds |	Mengimplementasikan Word Clouds Menggunakan `Wordclouds` Library Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
# Folium Maps |	Mengimplementasikan London Maps Menggunakan `Folium`.
# Preprocessing |	Student Melakukan Preproses Dataset Sebelum Menerapkan Visualisasi. | | Apakah Kode Berjalan Tanpa Ada Eror?
# Apakah Kode Berjalan Tanpa Ada Eror? |	Seluruh Kode Berfungsi Dan Dibuat Dengan Benar.
# Area Plot |	Menarik Informasi/Kesimpulan Berdasarkan Area Plot Yang Telah Student Buat
# Histogram |	Menarik Informasi/Kesimpulan Berdasarkan Histogram Yang Telah Student Buat
# Bar Chart |	Menarik Informasi/Kesimpulan Berdasarkan Bar Chart Yang Telah Student Buat
# Pie Chart |	Menarik Informasi/Kesimpulan Berdasarkan Pie Chart Yang Telah Student Buat
# Box Plot |	Menarik Informasi/Kesimpulan Berdasarkan Box Plot Yang Telah Student Buat
# Scatter Plot |	Menarik Informasi/Kesimpulan Berdasarkan Scatter Plot Yang Telah Student Buat
# Overall Analysis |	Menarik Informasi/Kesimpulan Dari Keseluruhan Plot Yang Dapat Menjawab Hipotesis.
#
# **Focus on "Graded-Function" sections.**
#
# ------------

# %%
#import package
import numpy as np
import pandas as pd

# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use(['ggplot'])

# %%
#load data dari folder dataset , download dari https://www.kaggle.com/jboysen/london-crime
df = pd.read_csv('dataset//london_crime_by_lsoa.csv')
df.shape
# Out:
# (13490604, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13490604 entries, 0 to 13490603
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   lsoa_code       object
#  1   borough         object
#  2   major_category  object
#  3   minor_category  object
#  4   value           int64
#  5   year            int64
#  6   month           int64
# dtypes: int64(3), object(4)
# memory usage: 720.5+ MB

# %%
# view the top 5 rows of the dataset
df.head()
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %%
# view the bottom 5 rows of the dataset
df.tail()
# Out:
#           lsoa_code     borough               major_category  \
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 13490599  Criminal Damage To Dwelling      0  2015      2
# 13490600            Personal Property      1  2015      6
# 13490601       Burglary in a Dwelling      0  2011      2
# 13490602            Business Property      0  2011      5
# 13490603                 Wounding/GBH      0  2015      6

# %%
# ambil data dengan criminal value > 0
criminal = df[df['value'] > 0]
criminal
# Out:
#           lsoa_code               borough               major_category  \
# 9         E01004177                Sutton           Theft and Handling
# 16        E01000086  Barking and Dagenham           Theft and Handling
# 24        E01001301                Ealing           Theft and Handling
# 25        E01001794               Hackney  Violence Against the Person
# 32        E01000733               Bromley              Criminal Damage
# ...             ...                   ...                          ...
# 13490581  E01000789               Bromley  Violence Against the Person
# 13490584  E01003301              Lewisham  Violence Against the Person
# 13490590  E01001679             Greenwich           Theft and Handling
# 13490592  E01033327              Lewisham  Violence Against the Person
# 13490600  E01002504            Hillingdon                      Robbery
#
#                             minor_category  value  year  month
# ...

# %%
# cek unique value borough pada data
criminal['borough'].value_counts()
# Out:
# Lambeth                   152784
# Croydon                   147203
# Southwark                 144362
# Ealing                    140006
# Newham                    137275
# Brent                     129925
# Lewisham                  128232
# Barnet                    127194
# Tower Hamlets             120099
# Wandsworth                118995
# Enfield                   117953
# Hackney                   116521
# Haringey                  116315
# Waltham Forest            114603
# Camden                    112029
# Islington                 111755
# Hillingdon                110614
# Westminster               110070
# Bromley                   109855
# Hounslow                  106561
# Redbridge                 105932
# Greenwich                 104654
# Hammersmith and Fulham     92084
# Barking and Dagenham       86849
# Havering                   82288
# Kensington and Chelsea     81295
# Harrow                     73993
# Bexley                     73948
# ...

# %%
# Data jumlah kriminal di tiap borough , sort dari paling banyak ke paling sedikit
criminal.groupby(["borough"])["value"].sum().sort_values(ascending=False)

#Kesimpulan : Westminster merupakan borough dengan kriminal paling banyak terjadi, City of London  merupakan borough dengan kriminal paling sedikit terjadi
# Out:
# borough
# Westminster               455028
# Lambeth                   292178
# Southwark                 278809
# Camden                    275147
# Newham                    262024
# Croydon                   260294
# Ealing                    251562
# Islington                 230286
# Tower Hamlets             228613
# Brent                     227551
# Hackney                   217119
# Lewisham                  215137
# Haringey                  213272
# Barnet                    212191
# Hillingdon                209680
# Wandsworth                204741
# Waltham Forest            203879
# Enfield                   193880
# Hounslow                  186772
# Hammersmith and Fulham    185259
# Bromley                   184349
# Redbridge                 183562
# Greenwich                 181568
# Kensington and Chelsea    171981
# Barking and Dagenham      149447
# Havering                  138947
# Harrow                    116848
# Merton                    115654
# ...

# %%
# Data jumlah major_category yang terjadi , sort dari paling banyak ke paling sedikit
criminal.groupby(["major_category"])["value"].sum().sort_values(ascending=False)

#Kesimpulan : Theft and Handling merupakan jenis kriminal paling banyak terjadi, Sexual Offences merupakan jenis kriminal paling sedikit terjadi
# Out:
# major_category
# Theft and Handling             2661861
# Violence Against the Person    1558081
# Burglary                        754293
# Criminal Damage                 630938
# Drugs                           470765
# Robbery                         258873
# Other Notifiable Offences       106349
# Fraud or Forgery                  5325
# Sexual Offences                   1273
# Name: value, dtype: int64

# %% [markdown]
# ## Visualizing Data using Matplotlib<a id="8"></a>

# %% [markdown]
# ## Area Pots (Series/Dataframe) <a id="12"></a>
#
# **Questions:** Bagaimana trend jumlah kriminal dari 3 borough di tahun 2008-2016?

# %%
# data kriminal di 3 borough

westminster=criminal[(criminal['borough'] == 'Westminster')].groupby(["year"])["value"].sum().reset_index(name ='Westminster').set_index('year')
lambeth=criminal[(criminal['borough'] == 'Lambeth')].groupby(["year"])["value"].sum().reset_index(name ='Lambeth').set_index('year')
southwark=criminal[(criminal['borough'] == 'Southwark')].groupby(["year"])["value"].sum().reset_index(name ='Southwark').set_index('year')

# gabung jadi satu
data_3_borough = pd.concat([westminster, lambeth,southwark], axis=1)
data_3_borough
# Out:
#       Westminster  Lambeth  Southwark
# year
# 2008        47846    31717      33470
# 2009        48456    31225      30623
# 2010        48116    31671      31320
# 2011        54243    33224      30723
# 2012        59226    33473      30737
# 2013        53852    31868      31128
# 2014        47564    31765      28912
# 2015        47395    33164      30260
# 2016        48330    34071      31636

# %%
# plot area 
data_3_borough.plot(kind='area', 
            stacked=False,
            figsize=(12,6),
            alpha=0.3)

plt.title('Perbandingan kriminal di Westminster,Lambeth dan Southwark 2008-2016') # add a title to the area plot
plt.ylabel('Jumlah Kriminal') # add y-label
plt.xlabel('Tahun') # add x-label

plt.show()

# %% [markdown]
# **Insight:** Pada borough Lambeth,Southwark trend kriminalnya cukup landai tidak ada perubahan yang cukup signifikan di tiap tahunnya, sedangkan di Westminster mengalami peningkatan jumlah kriminalitas yang signifikan pada tahun 2012

# %% [markdown]
# ## Histogram

# %%
data_3_borough

count, bin_edges = np.histogram(data_3_borough)

print(count)
print(bin_edges)
# Out:
# [13  5  0  0  0  0  6  0  2  1]
# [28912.  31943.4 34974.8 38006.2 41037.6 44069.  47100.4 50131.8 53163.2
#  56194.6 59226. ]

# %%
df.plot(kind="hist", 
             xticks = bin_edges, 
             figsize=(12,6),
             alpha=0.5
             )

plt.title("Distribusi Frekuensi Kriminalitas di Westminster,Lambeth dan Southwark 2008-2016")
plt.xlabel("Total Kriminalitas")
plt.ylabel("Frekuensi")
# Out:
# Text(0, 0.5, 'Frekuensi')

# %% [markdown]
# ## Bar Charts (Dataframe) <a id="10"></a>
#
# **Question:** Jumlah kriminal yang terjadi di Westminster di tahun 2008-2016?

# %%
#data kriminal di Westminster
westminster.plot(kind="bar", figsize=(12,6))


plt.xlabel('Tahun') # add to x-label to the plot
plt.ylabel('Jumlah') # add y-label to the plot
plt.title('Jumlah kriminal di Westminster tahun 2008-2016') # add title to the plot

plt.show()

# %% [markdown]
# **Insight:** Dari data yang tersedia, tahun 2012 merupakan tahun dengan jumlah kriminal paling banyak di Westminster

# %% [markdown]
# ## Pie Charts <a id="6"></a>
#
# **Question:** Jenis kriminal apa yang paling banyak terjadi di borough Westminster di tahun 2012

# %%
#ambil data kriminal Westminster di tahun 2012 
df_westminster_2012 = criminal[(criminal['borough'] == 'Westminster') & (criminal['year'] == 2012)]
df_westminster_2012
# Out:
#           lsoa_code      borough               major_category  \
# 785       E01004669  Westminster           Theft and Handling
# 1708      E01033597  Westminster                     Burglary
# 2168      E01004752  Westminster           Theft and Handling
# 3950      E01004727  Westminster           Theft and Handling
# 6193      E01004661  Westminster           Theft and Handling
# ...             ...          ...                          ...
# 13484960  E01004755  Westminster              Criminal Damage
# 13487823  E01004700  Westminster           Theft and Handling
# 13488301  E01004679  Westminster  Violence Against the Person
# 13489145  E01004709  Westminster  Violence Against the Person
# 13490545  E01004712  Westminster           Theft and Handling
#
#                          minor_category  value  year  month
# 785                         Other Theft      1  2012      7
# 1708        Burglary in Other Buildings      1  2012      7
# ...

# %%
# Data kriminal westminster tahun 2012 berdasarkan major_category : 
df_westminster_2012_criminal = df_westminster_2012.groupby(["major_category"])["value"].sum()

# Pie Chart
df_westminster_2012_criminal.plot(kind="pie",
                      figsize=(15, 6),
                      autopct='%1.1f%%',
                      startangle=90,
                      shadow=True,
                      labels=None,         
                      pctdistance=1.12,
                      explode=[0, 0.2, 0, 0, 0, 0, 0] 
                      )


# scale the title up by 12% to match pctdistance
plt.title('Jenis Kriminal di Westminster tahun 2012', y=1.12)

plt.axis('equal')

# add legend
plt.legend(labels=df_westminster_2012_criminal.index, loc='upper left')

plt.show()

# %% [markdown]
# **Insight:** Theft and Handling mendominasi kriminal di Westminster tahun 2012

# %% [markdown]
# ## Box Plots <a id="8"></a>

# %%
# Jumlah kriminalitas di Westminster  , Lambeth  , Southwark
data_3_borough.plot(kind="box", figsize=(15,9))
plt.title("Jumlah kriminalitas di Westminster  , Lambeth  , Southwark  2008-2016")
plt.ylabel("Total kriminalitas")
plt.xlabel("Borough")
# Out:
# Text(0.5, 0, 'Borough')

# %% [markdown]
# ## Scatter Plots <a id="10"></a>
#
#
# **Question:** Korelasi jumlah Kriminal di Westminster dan Lambeth perbulan tahun 2012?

# %%
#data Westminster per bulan di tahun 2012
df_westminster_2012_month = df_westminster_2012.groupby(["month"])["value"].sum().reset_index(name ='Westminster').set_index('month')
df_westminster_2012_month

#data Lambeth per bulan di tahun 2012
df_lambeth_2012 = criminal[(criminal['borough'] == 'Lambeth') & (criminal['year'] == 2012)]
df_lambeth_2012_month = df_lambeth_2012.groupby(["month"])["value"].sum().reset_index(name ='Lambeth').set_index('month')
df_lambeth_2012_month

# gabung jadi satu
data_borough_per_bulan = pd.concat([df_westminster_2012_month, df_lambeth_2012_month], axis=1)
data_borough_per_bulan
# Out:
#        Westminster  Lambeth
# month
# 1             5084     3154
# 2             4381     2311
# 3             5362     2995
# 4             4623     2736
# 5             5104     2745
# 6             4797     2887
# 7             5428     2748
# 8             5246     2872
# 9             4341     2698
# 10            4761     2756
# 11            4952     2873
# 12            5147     2698

# %%
data_borough_per_bulan.plot(kind='scatter', x='Westminster', y='Lambeth', figsize=(10, 6), color='darkblue')


plt.title("Korelasi jumlah Kriminal di Westminster dan Lambeth perbulan tahun 2012")
plt.xlabel('Westminster')
plt.ylabel('Lambeth')

plt.show()

# %% [markdown]
# **Insight:** tidak ada korelasi

# %% [markdown]
# ## Word Clouds <a id="8"></a>

# %%
# import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS

# %%
stopwords = set(STOPWORDS)

# %%
text =""
max_words=30000
data_borough =criminal.groupby(["borough"])["value"].sum().reset_index(name ='total_kriminal').set_index('borough')

total_kriminal = data_borough['total_kriminal'].sum()

# %%
# hitung berapa kali borough akan muncul

for borough in data_borough.index:
    borough_name = borough
    for s in " ,()-'":
        borough_name = "".join(borough_name.split(s))
    word_count= int(data_borough.loc[borough,"total_kriminal"] / float(total_kriminal) * max_words)
    text = text + ((borough_name + " ") * word_count)

print("panjang text: ", len(text))
# Out:
# panjang text:  306694

# %%
# instantiate a word cloud object
your_wordcloud = WordCloud(
    background_color='white',
    max_words=max_words,
    collocations= False,
    stopwords=stopwords
)

# generate the word cloud
your_wordcloud.generate(text)

# %%
fig = plt.figure(figsize=(15,6))
plt.imshow(your_wordcloud, interpolation='bilinear')

plt.axis('off')
plt.show()

# %% [markdown]
# ## Folium

# %%
import folium
from folium import plugins

# %%
# koordinat London yang menjadi pusat map
london_coordinate = [51.509865,-0.118092]

# data jumlah kriminal di setiap borough
df2=criminal.groupby(["borough"])["value"].sum()

# %%
#gabung dengan peta pembagian london borough supaya bisa mendapatkan heatmap kriminalitas di tiap borough
london_geo = r'https://raw.githubusercontent.com/radoi90/housequest-data/master/london_boroughs.geojson' #peta london borough
london_map=folium.Map(location=london_coordinate,zoom_start=10)

london_map.choropleth(
    geo_data=london_geo,
    name='choropleth',
    data=df2,
    columns=['borough', 'value'],
    key_on='feature.properties.name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Crime rate in boroughs of london'
    
)

# display london map
display(london_map)
# Out:
# C:\Users\Oscar Forendo\AppData\Local\Programs\Python\Python310\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ...

# %% [markdown]
# Tingkat kriminalitas tertinggi ada di tengah London
